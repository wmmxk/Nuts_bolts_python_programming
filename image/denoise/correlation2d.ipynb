# %% [markdown]
# #keyword:  Sobel filter using scipy
# https://stackoverflow.com/questions/7185655/applying-the-sobel-filter-using-scipy

# %%
from PIL import Image
import numpy as np
from scipy import signal, misc
import matplotlib.pyplot as plt

# %%
img_path = '../images/iPhone2.jpg'


import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(img_path)

# %%
image.shape
# Out:
# (768, 1024)

# %%
>>> from scipy import signal
>>> from scipy import misc

# %% [markdown]
# corr = signal.correlate2d(img[:,:,1], img[:,:,1], boundary='symm', mode='same')

# %% [markdown]
# import scipy
# corr =  scipy.signal.fftconvolve(img[:,:,1], img[:,:,0])

# %%
fft_re = np.fft.fft2(img[:,:,1])

# %%
fft_re = np.log(np.abs(fft_re))

# %%
fft_re.shape
# Out:
# (256, 256)

# %%
>>> plt.figure()
>>> plt.imshow(fft_re)
>>> plt.title('Original image')
>>> plt.show()

# %%
>>> plt.figure()
>>> plt.imshow(corr)
>>> plt.title('Original image')
>>> plt.show()

# %%
>>> plt.figure()
>>> plt.imshow(corr)
>>> plt.title('Original image')
>>> plt.show()

# %%
>>> plt.figure()
>>> plt.imshow(img[:,:,0])
>>> plt.title('Original image')
>>> plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# simple averaging filter without scaling parameter
mean_filter = np.ones((3,3))

# creating a guassian filter
x = cv2.getGaussianKernel(5,10)
gaussian = x*x.T

# %%
gaussian
# Out:
# array([[ 0.0392052 ,  0.03979772,  0.0399972 ,  0.03979772,  0.0392052 ],
#        [ 0.03979772,  0.04039918,  0.04060168,  0.04039918,  0.03979772],
#        [ 0.0399972 ,  0.04060168,  0.0408052 ,  0.04060168,  0.0399972 ],
#        [ 0.03979772,  0.04039918,  0.04060168,  0.04039918,  0.03979772],
#        [ 0.0392052 ,  0.03979772,  0.0399972 ,  0.03979772,  0.0392052 ]])

# %%
# different edge detecting filters
# scharr in x-direction
scharr = np.array([[-3, 0, 3],
                   [-10,0,10],
                   [-3, 0, 3]])
# sobel in x direction
sobel_x= np.array([[-1, 0, 1],
                   [-2, 0, 2],
                   [-1, 0, 1]])
# sobel in y direction
sobel_y= np.array([[-1,-2,-1],
                   [0, 0, 0],
                   [1, 2, 1]])
# laplacian
laplacian=np.array([[0, 1, 0],
                    [1,-4, 1],
                    [0, 1, 0]])

filters = [mean_filter, gaussian, laplacian, sobel_x, sobel_y, scharr]
filter_name = ['mean_filter', 'gaussian','laplacian', 'sobel_x', \
                'sobel_y', 'scharr_x']
fft_filters = [np.fft.fft2(x) for x in filters]
fft_shift = [np.fft.fftshift(y) for y in fft_filters]
mag_spectrum = [np.log(np.abs(z)+1) for z in fft_shift]

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(mag_spectrum[i],cmap = 'gray')
    plt.title(filter_name[i]), plt.xticks([]), plt.yticks([])

plt.show()
