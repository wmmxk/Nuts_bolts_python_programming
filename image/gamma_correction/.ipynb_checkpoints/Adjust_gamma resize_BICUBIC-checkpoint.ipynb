# %%
from __future__ import print_function, unicode_literals, absolute_import
import sys

from PIL import Image

# %%
def do_gamma(im, gamma):
    """Fast gamma correction with PIL's image.point() method"""
    invert_gamma = 1.0/gamma
    lut = [pow(x/255., invert_gamma) * 255 for x in range(256)]
    lut = lut*3 # need one set of data for each band for RGB
    im = im.point(lut)
    return im

# %%
img = Image.open("./images/dark.jpg")
img_c = do_gamma(img,1.4)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x7F935D4470F0>

# %%
img_c
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F935D436C18>

# %%
# resize
img.resize((200,200),resample = Image.BICUBIC)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F935D3DBC50>

# %%
from keras import backend as K
img = np.asarray(img, dtype=K.floatx())
# Out:
# Using TensorFlow backend.
