# %%
from PIL import Image
im1 = Image.open("./images/dog.jpg")

# %%
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=263x192 at 0x7F01400AFCF8>

# %%
IMAGE_10 = './images/dog10.jpeg'
im1.save(IMAGE_10,"JPEG", quality=10)
im10 = Image.open(IMAGE_10)

# %%
im10
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=263x192 at 0x7F01400B90B8>
