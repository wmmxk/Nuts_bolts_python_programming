# %%
import PIL
from PIL import Image
import numpy as np

# %%
img = Image.open('./images/cat.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=260x194 at 0x7FF1E15AA350>

# %%
iarray = np.asarray(img)
print iarray.shape
# Out:
# (194, 260, 3)

# %%
img_back = Image.fromarray(np.uint8(iarray))

# %%
img_back
# Out:
# <PIL.Image.Image image mode=RGB size=260x194 at 0x7FF1E15D4290>
