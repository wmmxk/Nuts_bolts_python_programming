# %%
#1. customize the content of a legend
#2. customize the loation
#3. make the legend transparent

# %%
x = range(10)
y = [i*2 for i in x]
z = [i*3 for i in x]
q = [i*1.5 for i in x]

# %%
colors = ["#F47105","#1BACFF","#FDA805"]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure(figsize=(5,4))


ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.9)
fig.subplots_adjust(bottom=0.16)
fig.subplots_adjust(left=0.16)

ax.set_xlabel('Episodes')
ax.set_ylabel('Accuracy')


plt.plot(x,y,color=colors[0],label=x)

plt.plot(x,z,color=colors[1],label=x)

plt.plot(x,q,color=colors[2],label=x)

# plt.xticks(np.arange(0, max(episodes[0])+1, 50000))

L = plt.legend()


L.get_frame().set_facecolor('none')

L.get_texts()[0].set_text('Request ratio')
L.get_texts()[1].set_text('Gap between two accuracy')


axes = plt.gca()

axes.set_ylim([0,23])


plt.show()
# Out:
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure(figsize=(5,4))


ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.9)
fig.subplots_adjust(bottom=0.16)
fig.subplots_adjust(left=0.16)

ax.set_xlabel('Episodes')
ax.set_ylabel('Accuracy')


plt.plot(x,y,color=colors[0],label=x)

plt.plot(x,z,color=colors[1],label=x)

plt.plot(x,q,color=colors[2],label=x)


# add the legend on the topright
L = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

#L = plt.legend()



axes = plt.gca()

axes.set_ylim([0,22])


L.get_texts()[0].set_text('Request ratio')
L.get_texts()[1].set_text('Gap between two accuracy')

L.get_frame().set_facecolor('none')

plt.show()

# The bbox_inches parameter makes sure the legend is not cut at the boundary
fig.savefig("../out_fig/error.pdf", bbox_inches='tight')
